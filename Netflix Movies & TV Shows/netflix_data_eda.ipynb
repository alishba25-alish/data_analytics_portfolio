# %%
import pandas as pd
import numpy as np

# # Load the dataset
netflix_data = pd.read_csv("C:/Users/DELL/Documents/Netflix Dataset/netflix_titles_nov_2019.csv")
print(netflix_data.head())
# Out:
#     show_id                                title                    director  \
# 0  81193313                            Chocolate                         NaN
# 1  81197050  Guatemala: Heart of the Mayan World  Luis Ara, Ignacio Jaunsolo
# 2  81213894                      The Zoya Factor             Abhishek Sharma
# 3  81082007                            Atlantics                   Mati Diop
# 4  80213643                      Chip and Potato                         NaN
#
#                                                 cast  \
# 0  Ha Ji-won, Yoon Kye-sang, Jang Seung-jo, Kang ...
# 1                                  Christian Morales
# 2  Sonam Kapoor, Dulquer Salmaan, Sanjay Kapoor, ...
# 3  Mama Sane, Amadou Mbow, Ibrahima Traore, Nicol...
# 4  Abigail Oliver, Andrea Libman, Briana Buckmast...
#
#                     country         date_added  release_year rating  \
# 0               South Korea  November 30, 2019          2019  TV-14
# 1                       NaN  November 30, 2019          2019   TV-G
# 2                     India  November 30, 2019          2019  TV-14
# 3  France, Senegal, Belgium  November 29, 2019          2019  TV-14
# 4    Canada, United Kingdom                NaN          2019   TV-Y
#
#     duration                                          listed_in  \
# 0   1 Season  International TV Shows, Korean TV Shows, Roman...
# 1     67 min                Documentaries, International Movies
# 2    135 min             Comedies, Dramas, International Movies
# 3    106 min   Dramas, Independent Movies, International Movies
# 4  2 Seasons                                           Kids' TV
#
#                                          description     type
# 0  Brought together by meaningful meals in the pa...  TV Show
# 1  From Sierra de las Minas to Esquipulas, explor...    Movie
# 2  A goofy copywriter unwittingly convinces the I...    Movie
# 3  Arranged to marry a rich man, young Ada is cru...    Movie
# 4  Lovable pug Chip starts kindergarten, makes ne...  TV Show

# %%
print(netflix_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5837 entries, 0 to 5836
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       5837 non-null   int64
#  1   title         5837 non-null   object
#  2   director      3936 non-null   object
#  3   cast          5281 non-null   object
#  4   country       5410 non-null   object
#  5   date_added    5195 non-null   object
#  6   release_year  5837 non-null   int64
#  7   rating        5827 non-null   object
#  8   duration      5837 non-null   object
#  9   listed_in     5837 non-null   object
#  10  description   5837 non-null   object
#  11  type          5837 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 547.3+ KB
# None

# %%
# Checking null values
print(netflix_data.isnull().sum())
# Out:
# show_id            0
# title              0
# director        1901
# cast             556
# country          427
# date_added       642
# release_year       0
# rating            10
# duration           0
# listed_in          0
# description        0
# type               0
# dtype: int64

# %%
print("Total duplicate rows:", netflix_data.duplicated().sum())
# Out:
# Total duplicate rows: 0

# %%
#Fill null values with Not Rated in rating column
netflix_data['rating'] = netflix_data['rating'].fillna('Not Rated')

#Fill null values with Anonymous in Director column
netflix_data['director'] = netflix_data['director'].fillna('Anonymous')

#Fill null values with Unknown in Cast column
netflix_data['cast'] = netflix_data['cast'].fillna('Unknown')

#Fill null values with Unknown in Country column
netflix_data['country'] =netflix_data['country'].fillna('Unknown')


# netflix_data.info()

# %%
#Convert date added datatype into int
netflix_data['date_added'] = pd.to_datetime(netflix_data['date_added'], errors='coerce')

#Fill date_added column with Date: 01-01 of release year column
netflix_data['date_added'] = netflix_data['date_added'].fillna(pd.to_datetime(netflix_data['release_year'].astype(str) + '-01-01', errors='coerce'))

print(netflix_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5837 entries, 0 to 5836
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       5837 non-null   int64
#  1   title         5837 non-null   object
#  2   director      5837 non-null   object
#  3   cast          5837 non-null   object
#  4   country       5837 non-null   object
#  5   date_added    5837 non-null   datetime64[ns]
#  6   release_year  5837 non-null   int64
#  7   rating        5837 non-null   object
#  8   duration      5837 non-null   object
#  9   listed_in     5837 non-null   object
#  10  description   5837 non-null   object
#  11  type          5837 non-null   object
# dtypes: datetime64[ns](1), int64(2), object(9)
# memory usage: 547.3+ KB
# None

# %%
#Column Transformation

#Splitting date_added column into year and month
netflix_data['year_added'] = netflix_data['date_added'].dt.year 

netflix_data['month_added'] = netflix_data['date_added'].dt.month

# %%
import re

# Movies: extract minutes only
def extract_movie_minutes(duration):
    if pd.isna(duration):
        return 0
    # find the number before 'min'
    match = re.search(r'(\d+)\s*min', duration)
    if match:
        return float(match.group(1))
    return 0

# Shows: extract number of seasons only
def extract_show_seasons(duration):
    if pd.isna(duration):
        return 0
    # find number before 'Season' or 'Seasons'
    match = re.search(r'(\d+)\s*Season', duration)
    if match:
        return float(match.group(1))
    return 0

# Apply to dataframe
netflix_data['movie_duration'] = netflix_data.apply(
    lambda x: extract_movie_minutes(x['duration']) if x['type']=='Movie' else 0, axis=1
)

netflix_data['show_duration'] = netflix_data.apply(
    lambda x: extract_show_seasons(x['duration']) if x['type']=='TV Show' else 0, axis=1
)

# Check result
print(netflix_data[['title','type','duration','movie_duration','show_duration']].head(20))
# Out:
#                                      title     type   duration  \
# 0                                Chocolate  TV Show   1 Season
# 1      Guatemala: Heart of the Mayan World    Movie     67 min
# 2                          The Zoya Factor    Movie    135 min
# 3                                Atlantics    Movie    106 min
# 4                          Chip and Potato  TV Show  2 Seasons
# 5                             Crazy people    Movie    107 min
# 6                           I Lost My Body    Movie     81 min
# 7   Kalushi: The Story of Solomon Mahlangu    Movie    107 min
# 8                         La Reina del Sur  TV Show  2 Seasons
# 9                     Lagos Real Fake Life    Movie    118 min
# 10                                  Payday    Movie    110 min
# 11                    Sugar Rush Christmas  TV Show   1 Season
# 12                      The Accidental Spy    Movie    104 min
# 13                    The Charming Stepmom  TV Show   1 Season
# 14                              The Island    Movie     93 min
# 15                 The Movies That Made Us  TV Show   1 Season
# 16                            Holiday Rush    Movie     94 min
# 17                                  Levius  TV Show   1 Season
# 18                         Lugar de Mulher  TV Show   1 Season
# 19                    Merry Happy Whatever  TV Show   1 Season
#
#     movie_duration  show_duration
# 0              0.0            1.0
# 1             67.0            0.0
# 2            135.0            0.0
# 3            106.0            0.0
# 4              0.0            2.0
# 5            107.0            0.0
# 6             81.0            0.0
# 7            107.0            0.0
# 8              0.0            2.0
# 9            118.0            0.0
# 10           110.0            0.0
# 11             0.0            1.0
# 12           104.0            0.0
# 13             0.0            1.0
# 14            93.0            0.0
# 15             0.0            1.0
# 16            94.0            0.0
# 17             0.0            1.0
# 18             0.0            1.0
# 19             0.0            1.0

# %%
# Copy the original Dataframe for exploding
netflix_data_exploded = netflix_data.copy()

# Checking Unique Values in listed_in Column
print(netflix_data['listed_in'].unique())

# Split the listed_in Column into list
netflix_data_exploded['listed_in_split'] = netflix_data_exploded['listed_in'].str.split(',')

# Removes Spaces
netflix_data_exploded['listed_in_split'] = netflix_data_exploded['listed_in_split'].apply(lambda x: [i.strip() for i in x])

# Explode into multiple rows not columns
netflix_data_exploded = netflix_data_exploded.explode('listed_in_split')

print(netflix_data.info())
# Out:
# ['International TV Shows, Korean TV Shows, Romantic TV Shows'
#  'Documentaries, International Movies'
#  'Comedies, Dramas, International Movies'
#  'Dramas, Independent Movies, International Movies' "Kids' TV"
#  'Comedies, International Movies, Thrillers'
#  'Dramas, International Movies'
#  'Crime TV Shows, International TV Shows, Spanish-Language TV Shows'
#  'Comedies, International Movies'
#  'Comedies, Independent Movies, International Movies' 'Reality TV'
#  'Action & Adventure, Comedies, International Movies'
#  'International TV Shows, Romantic TV Shows, TV Comedies'
#  'Dramas, International Movies, Thrillers' 'Docuseries'
#  'Children & Family Movies, Dramas' 'Anime Series, International TV Shows'
#  'International TV Shows, Stand-Up Comedy & Talk Shows, TV Comedies'
#  'TV Comedies' 'International TV Shows, TV Comedies, TV Dramas'
#  'Dramas, Thrillers' 'Action & Adventure, Dramas'
#  'Comedies, International Movies, Romantic Movies'
#  'Children & Family Movies, Comedies' 'Dramas, Independent Movies'
#  'Dramas' 'Stand-Up Comedy' 'Children & Family Movies'
#  'Crime TV Shows, International TV Shows, TV Dramas' 'Movies'
#  'International TV Shows, Spanish-Language TV Shows, Stand-Up Comedy & Talk Shows'
#  'Crime TV Shows, TV Dramas, TV Mysteries'
#  'Action & Adventure, Dramas, International Movies' 'Thrillers'
#  'Action & Adventure, Children & Family Movies, Comedies'
#  'Crime TV Shows, International TV Shows, Korean TV Shows'
#  'Children & Family Movies, Classic Movies' 'Action & Adventure'
#  'International TV Shows, TV Comedies, TV Sci-Fi & Fantasy'
#  'Action & Adventure, Sci-Fi & Fantasy' "Anime Series, Kids' TV"
#  'TV Dramas' 'Action & Adventure, Anime Features, International Movies'
#  'Crime TV Shows, Docuseries' 'Documentaries, Sports Movies'
#  'International TV Shows, Reality TV'
#  "Kids' TV, TV Action & Adventure, TV Sci-Fi & Fantasy"
#  "Kids' TV, TV Comedies"
#  'Children & Family Movies, Comedies, Romantic Movies'
#  'Comedies, Dramas, Romantic Movies' 'Comedies, Cult Movies' 'Comedies'
#  'Documentaries' 'Horror Movies, Sci-Fi & Fantasy, Thrillers'
#  'Dramas, International Movies, Romantic Movies'
#  'Comedies, Sci-Fi & Fantasy' 'International TV Shows, TV Dramas'
#  'Comedies, Sports Movies'
#  'Documentaries, International Movies, Sports Movies'
#  'Action & Adventure, Classic Movies, International Movies'
#  'Comedies, Romantic Movies' 'Horror Movies, Thrillers'
#  'Classic Movies, Comedies, Sports Movies'
#  'Classic Movies, Dramas, Independent Movies'
#  'Crime TV Shows, Docuseries, International TV Shows'
#  'Comedies, Dramas, Independent Movies' 'Cult Movies, Dramas, Thrillers'
#  'International TV Shows, Reality TV, Spanish-Language TV Shows'
#  'International TV Shows, TV Dramas, Teen TV Shows'
#  'British TV Shows, International TV Shows, TV Dramas'
#  'Action & Adventure, Dramas, Independent Movies'
#  'Horror Movies, Independent Movies'
#  'International TV Shows, Romantic TV Shows' 'Dramas, Romantic Movies'
#  'Children & Family Movies, Music & Musicals'
#  'Anime Series, Teen TV Shows' 'Anime Features'
#  'International TV Shows, Romantic TV Shows, TV Dramas'
#  'Anime Features, International Movies, Romantic Movies'
#  'International TV Shows, TV Action & Adventure, TV Dramas'
#  'Docuseries, Reality TV'
#  'International TV Shows, Romantic TV Shows, TV Action & Adventure'
#  'Documentaries, Music & Musicals' 'Docuseries, Spanish-Language TV Shows'
#  'International TV Shows, Korean TV Shows, TV Dramas'
#  'Dramas, Independent Movies, LGBTQ Movies'
#  'International TV Shows, Romantic TV Shows, Teen TV Shows'
#  'International TV Shows, Korean TV Shows, Stand-Up Comedy & Talk Shows'
#  'British TV Shows, Docuseries, International TV Shows'
#  "Kids' TV, TV Action & Adventure, TV Comedies"
#  'Action & Adventure, Comedies, Romantic Movies'
#  'Comedies, Dramas, LGBTQ Movies' 'British TV Shows, Reality TV'
#  'International Movies, Thrillers'
#  'International TV Shows, Romantic TV Shows, Spanish-Language TV Shows'
#  'British TV Shows, International TV Shows, TV Comedies'
#  'Action & Adventure, International Movies, Sci-Fi & Fantasy'
#  'Comedies, Independent Movies, Romantic Movies'
#  'British TV Shows, TV Comedies' 'Horror Movies'
#  'British TV Shows, International TV Shows, Reality TV'
#  'Docuseries, International TV Shows, Science & Nature TV'
#  'TV Comedies, TV Dramas, Teen TV Shows'
#  'International TV Shows, Reality TV, TV Comedies'
#  'Classic Movies, Dramas, Romantic Movies' 'Classic Movies, Dramas'
#  'Action & Adventure, Classic Movies' 'Action & Adventure, Comedies'
#  'Action & Adventure, International Movies'
#  'Dramas, International Movies, LGBTQ Movies'
#  'Comedies, Cult Movies, Dramas'
#  'Action & Adventure, Classic Movies, Sci-Fi & Fantasy'
#  'Classic Movies, Comedies, Music & Musicals'
#  'Anime Series, International TV Shows, Teen TV Shows'
#  'Children & Family Movies, Dramas, Romantic Movies'
#  'Dramas, Sports Movies'
#  'Action & Adventure, Horror Movies, Sci-Fi & Fantasy'
#  'Classic Movies, Dramas, International Movies'
#  'Action & Adventure, Classic Movies, Cult Movies'
#  'Anime Series, Romantic TV Shows, Teen TV Shows'
#  'Anime Series, Romantic TV Shows'
#  'Docuseries, Science & Nature TV, TV Dramas'
#  'Action & Adventure, Classic Movies, Dramas'
#  'Action & Adventure, Comedies, Independent Movies'
#  'Action & Adventure, Classic Movies, Comedies'
#  'Classic Movies, Horror Movies, Thrillers' 'Dramas, Music & Musicals'
#  'Dramas, Faith & Spirituality'
#  'International TV Shows, Spanish-Language TV Shows, TV Dramas'
#  'International TV Shows, TV Dramas, TV Mysteries'
#  'Documentaries, International Movies, Music & Musicals'
#  'Comedies, Horror Movies'
#  'Crime TV Shows, International TV Shows, TV Action & Adventure'
#  'Docuseries, International TV Shows' 'Comedies, Dramas'
#  "Kids' TV, TV Dramas, Teen TV Shows" 'International Movies'
#  'Reality TV, TV Comedies, TV Horror'
#  'Horror Movies, Independent Movies, Thrillers' 'TV Comedies, TV Dramas'
#  'International TV Shows, TV Action & Adventure, TV Mysteries'
#  'TV Action & Adventure, TV Comedies, TV Horror'
#  'Horror Movies, International Movies'
#  'Action & Adventure, Independent Movies' 'Documentaries, Stand-Up Comedy'
#  'Cult Movies, Horror Movies, Independent Movies'
#  'Action & Adventure, Comedies, Sci-Fi & Fantasy'
#  "British TV Shows, Kids' TV"
#  'Docuseries, Reality TV, Science & Nature TV' "Kids' TV, Korean TV Shows"
#  'International TV Shows, Spanish-Language TV Shows, TV Comedies'
#  'International TV Shows, TV Comedies' 'Docuseries, Science & Nature TV'
#  'Dramas, Faith & Spirituality, International Movies'
#  "Kids' TV, TV Thrillers" 'Anime Series'
#  'Reality TV, TV Horror, TV Thrillers'
#  'International Movies, Music & Musicals'
#  'International TV Shows, Korean TV Shows, TV Action & Adventure'
#  "British TV Shows, Kids' TV, TV Thrillers"
#  'British TV Shows, Crime TV Shows, International TV Shows'
#  "Kids' TV, TV Action & Adventure, TV Dramas"
#  'Anime Series, Crime TV Shows' 'Cult Movies, Horror Movies'
#  'Children & Family Movies, Sci-Fi & Fantasy'
#  'Sci-Fi & Fantasy, Thrillers'
#  'Horror Movies, International Movies, Thrillers'
#  'Classic Movies, Dramas, Sports Movies'
#  'Children & Family Movies, Comedies, Sports Movies'
#  'Comedies, Cult Movies, International Movies'
#  'Dramas, Romantic Movies, Sci-Fi & Fantasy'
#  'Dramas, Independent Movies, Thrillers'
#  'Crime TV Shows, TV Action & Adventure, TV Dramas'
#  'Dramas, Sci-Fi & Fantasy, Thrillers'
#  'Anime Features, Music & Musicals, Sci-Fi & Fantasy'
#  'International Movies, Romantic Movies'
#  'International TV Shows, TV Dramas, TV Horror'
#  'Comedies, International Movies, Music & Musicals'
#  'TV Horror, TV Mysteries, TV Thrillers'
#  'TV Action & Adventure, TV Comedies, TV Sci-Fi & Fantasy'
#  'TV Horror, Teen TV Shows' 'Crime TV Shows, TV Dramas, TV Thrillers'
#  'Anime Series, International TV Shows, TV Horror'
#  'Crime TV Shows, TV Dramas'
#  'TV Action & Adventure, TV Dramas, TV Sci-Fi & Fantasy'
#  'International TV Shows, TV Dramas, TV Thrillers'
#  'Comedies, Independent Movies, Thrillers'
#  'TV Action & Adventure, TV Sci-Fi & Fantasy'
#  'British TV Shows, Docuseries, Science & Nature TV'
#  'Crime TV Shows, TV Horror, TV Mysteries'
#  'British TV Shows, Crime TV Shows, Docuseries'
#  'Classic Movies, Comedies, Cult Movies'
#  'Action & Adventure, Romantic Movies'
#  'Classic & Cult TV, TV Action & Adventure, TV Dramas'
#  'Children & Family Movies, Comedies, Dramas'
#  'Anime Series, Crime TV Shows, International TV Shows'
#  'Dramas, International Movies, Sci-Fi & Fantasy'
#  'Children & Family Movies, Comedies, Sci-Fi & Fantasy'
#  'International TV Shows, Spanish-Language TV Shows, TV Action & Adventure'
#  'Stand-Up Comedy & Talk Shows, TV Comedies'
#  'TV Comedies, TV Dramas, TV Horror'
#  'Children & Family Movies, Comedies, LGBTQ Movies'
#  'Romantic TV Shows, TV Comedies, TV Dramas'
#  "Kids' TV, TV Comedies, TV Dramas"
#  'Children & Family Movies, Comedies, International Movies'
#  "Kids' TV, TV Action & Adventure"
#  'Comedies, International Movies, Sports Movies'
#  'Classic Movies, Comedies, International Movies'
#  'Dramas, Horror Movies, Sci-Fi & Fantasy'
#  'Crime TV Shows, International TV Shows, Romantic TV Shows'
#  'International TV Shows, TV Mysteries, TV Thrillers'
#  'Action & Adventure, Dramas, Sci-Fi & Fantasy'
#  'Comedies, Cult Movies, LGBTQ Movies' 'TV Shows'
#  'Comedies, Horror Movies, International Movies'
#  'TV Action & Adventure, TV Dramas, TV Mysteries' 'International TV Shows'
#  'International TV Shows, TV Horror, TV Mysteries'
#  'British TV Shows, Reality TV, Romantic TV Shows'
#  'British TV Shows, Docuseries'
#  'International TV Shows, TV Action & Adventure, TV Sci-Fi & Fantasy'
#  'Docuseries, International TV Shows, Reality TV'
#  "British TV Shows, Kids' TV, TV Dramas"
#  'TV Horror, TV Mysteries, TV Sci-Fi & Fantasy' 'Docuseries, TV Dramas'
#  'TV Dramas, TV Sci-Fi & Fantasy' 'Classic Movies, Comedies, Dramas'
#  'Action & Adventure, Children & Family Movies, Sci-Fi & Fantasy'
#  'Children & Family Movies, Documentaries'
#  'Classic Movies, Dramas, LGBTQ Movies'
#  'Children & Family Movies, Independent Movies'
#  'Classic Movies, Dramas, Thrillers'
#  "Kids' TV, Korean TV Shows, TV Comedies"
#  'Horror Movies, International Movies, Romantic Movies' 'Romantic Movies'
#  'Crime TV Shows, Docuseries, Science & Nature TV'
#  'Dramas, Independent Movies, Music & Musicals'
#  'Crime TV Shows, International TV Shows, TV Comedies'
#  'International Movies, Music & Musicals, Thrillers'
#  'Horror Movies, Independent Movies, International Movies'
#  'Documentaries, Faith & Spirituality'
#  "Kids' TV, Spanish-Language TV Shows, Teen TV Shows"
#  'Romantic TV Shows, TV Dramas' 'TV Dramas, Teen TV Shows'
#  'Anime Series, International TV Shows, TV Thrillers'
#  'Independent Movies, Thrillers'
#  'International TV Shows, TV Dramas, TV Sci-Fi & Fantasy'
#  'International Movies, Sci-Fi & Fantasy, Thrillers'
#  'Children & Family Movies, Dramas, International Movies'
#  'Comedies, Horror Movies, Independent Movies'
#  'Dramas, Independent Movies, Romantic Movies'
#  'Comedies, Faith & Spirituality, Romantic Movies'
#  'Anime Features, International Movies'
#  'Classic Movies, Cult Movies, Horror Movies'
#  'Crime TV Shows, Spanish-Language TV Shows, TV Dramas'
#  'Documentaries, LGBTQ Movies' 'Dramas, Music & Musicals, Romantic Movies'
#  'Action & Adventure, Romantic Movies, Sci-Fi & Fantasy'
#  'Action & Adventure, International Movies, Sports Movies'
#  'Action & Adventure, Horror Movies, International Movies'
#  'Stand-Up Comedy & Talk Shows'
#  'Romantic TV Shows, TV Action & Adventure, TV Dramas'
#  'Action & Adventure, Independent Movies, Sci-Fi & Fantasy'
#  'Horror Movies, LGBTQ Movies, Thrillers' 'TV Dramas, TV Thrillers'
#  'Comedies, Music & Musicals, Sports Movies'
#  'Crime TV Shows, TV Action & Adventure, TV Sci-Fi & Fantasy'
#  'Crime TV Shows, TV Action & Adventure'
#  'Dramas, Independent Movies, Sports Movies'
#  'Comedies, International Movies, Sci-Fi & Fantasy'
#  'Action & Adventure, Sci-Fi & Fantasy, Thrillers'
#  'Action & Adventure, International Movies, Music & Musicals'
#  'Dramas, International Movies, Music & Musicals'
#  "British TV Shows, Kids' TV, TV Comedies"
#  "Kids' TV, Spanish-Language TV Shows"
#  'Action & Adventure, Comedies, Dramas'
#  'Crime TV Shows, TV Comedies, TV Dramas'
#  'International Movies, Sci-Fi & Fantasy'
#  'Classic & Cult TV, TV Action & Adventure, TV Horror'
#  'Action & Adventure, Independent Movies, International Movies'
#  'Classic & Cult TV, TV Dramas, TV Sci-Fi & Fantasy'
#  'Action & Adventure, Cult Movies, International Movies'
#  'International TV Shows, TV Action & Adventure, TV Comedies'
#  'TV Horror, TV Mysteries, Teen TV Shows'
#  'Dramas, Romantic Movies, Sports Movies'
#  'Children & Family Movies, Comedies, Faith & Spirituality'
#  'Dramas, Independent Movies, Sci-Fi & Fantasy'
#  'Action & Adventure, Horror Movies' 'Romantic TV Shows, TV Comedies'
#  'Dramas, International Movies, Sports Movies'
#  'TV Action & Adventure, TV Dramas, TV Horror'
#  "Kids' TV, Reality TV, Science & Nature TV"
#  'TV Dramas, TV Sci-Fi & Fantasy, Teen TV Shows'
#  'International Movies, Romantic Movies, Sci-Fi & Fantasy'
#  'TV Comedies, TV Horror, TV Thrillers'
#  'International TV Shows, Reality TV, Romantic TV Shows'
#  'Comedies, Dramas, Music & Musicals'
#  'TV Dramas, TV Mysteries, TV Sci-Fi & Fantasy'
#  'Action & Adventure, Children & Family Movies, Independent Movies'
#  'Action & Adventure, Comedies, Cult Movies'
#  'TV Action & Adventure, TV Horror, TV Sci-Fi & Fantasy'
#  'TV Action & Adventure' 'TV Dramas, TV Horror, TV Mysteries'
#  'Action & Adventure, International Movies, Romantic Movies'
#  'Reality TV, Science & Nature TV'
#  'Independent Movies, International Movies, Thrillers'
#  'Comedies, Independent Movies'
#  'Children & Family Movies, Dramas, Independent Movies'
#  'Comedies, Cult Movies, Independent Movies' 'Docuseries, TV Comedies'
#  'International TV Shows, Spanish-Language TV Shows, TV Horror'
#  'TV Action & Adventure, TV Mysteries, TV Sci-Fi & Fantasy'
#  'Reality TV, Romantic TV Shows'
#  'Children & Family Movies, Dramas, Faith & Spirituality'
#  'Comedies, LGBTQ Movies'
#  'Anime Series, International TV Shows, Romantic TV Shows'
#  'Horror Movies, Sci-Fi & Fantasy'
#  'Action & Adventure, Children & Family Movies'
#  'Comedies, Dramas, Sports Movies' 'Dramas, Sci-Fi & Fantasy'
#  'Crime TV Shows, TV Action & Adventure, TV Thrillers'
#  'Classic & Cult TV, Crime TV Shows, International TV Shows'
#  'Anime Series, Crime TV Shows, TV Thrillers'
#  'Documentaries, Faith & Spirituality, International Movies'
#  'Independent Movies'
#  'Action & Adventure, Children & Family Movies, Classic Movies'
#  'Anime Features, Children & Family Movies'
#  'Classic Movies, Cult Movies, Dramas'
#  'Action & Adventure, Cult Movies, Sci-Fi & Fantasy'
#  'Action & Adventure, Sports Movies' 'Music & Musicals'
#  'Music & Musicals, Stand-Up Comedy'
#  'Action & Adventure, Faith & Spirituality, Sci-Fi & Fantasy'
#  'Crime TV Shows, Romantic TV Shows, TV Dramas'
#  'Crime TV Shows, Spanish-Language TV Shows, TV Action & Adventure'
#  'British TV Shows, International TV Shows, TV Action & Adventure'
#  'Sci-Fi & Fantasy' 'International TV Shows, TV Horror, TV Thrillers'
#  'British TV Shows, TV Comedies, TV Dramas' 'Reality TV, TV Comedies'
#  'Action & Adventure, Dramas, Faith & Spirituality'
#  'Action & Adventure, Children & Family Movies, Dramas'
#  'TV Comedies, TV Sci-Fi & Fantasy, Teen TV Shows'
#  'Crime TV Shows, TV Action & Adventure, TV Comedies'
#  'International Movies, LGBTQ Movies, Romantic Movies'
#  'International TV Shows, Korean TV Shows, TV Comedies'
#  'Crime TV Shows, International TV Shows, Reality TV'
#  'International TV Shows, Reality TV, TV Action & Adventure'
#  'Children & Family Movies, Dramas, Sports Movies'
#  'TV Comedies, TV Sci-Fi & Fantasy' 'Spanish-Language TV Shows, TV Dramas'
#  'Romantic TV Shows, Spanish-Language TV Shows, TV Comedies'
#  "Kids' TV, TV Dramas"
#  'Crime TV Shows, International TV Shows, TV Sci-Fi & Fantasy'
#  'Comedies, International Movies, LGBTQ Movies'
#  'Dramas, Music & Musicals, Sports Movies'
#  'Anime Series, TV Horror, TV Thrillers'
#  'British TV Shows, International TV Shows, Romantic TV Shows'
#  "Crime TV Shows, Kids' TV"
#  'Horror Movies, International Movies, Sci-Fi & Fantasy'
#  'TV Comedies, TV Mysteries' 'Comedies, Music & Musicals'
#  'British TV Shows, Docuseries, TV Comedies' 'Comedies, Documentaries'
#  'British TV Shows, Classic & Cult TV, International TV Shows'
#  'International Movies, Music & Musicals, Romantic Movies'
#  'Action & Adventure, Documentaries, International Movies'
#  'British TV Shows, Classic & Cult TV, TV Comedies'
#  'Reality TV, Science & Nature TV, TV Action & Adventure'
#  'TV Comedies, TV Dramas, TV Mysteries'
#  'Independent Movies, Sci-Fi & Fantasy, Thrillers'
#  'Crime TV Shows, TV Comedies, Teen TV Shows'
#  'Docuseries, International TV Shows, Spanish-Language TV Shows'
#  "Docuseries, Kids' TV, Science & Nature TV"
#  'Comedies, Cult Movies, Horror Movies'
#  'Reality TV, Spanish-Language TV Shows'
#  'Comedies, Independent Movies, LGBTQ Movies'
#  'Comedies, Faith & Spirituality, International Movies'
#  'Documentaries, Horror Movies'
#  'Action & Adventure, Horror Movies, Independent Movies'
#  'Action & Adventure, Anime Features, Sci-Fi & Fantasy'
#  'Crime TV Shows, Docuseries, TV Mysteries'
#  'Children & Family Movies, Faith & Spirituality'
#  "Crime TV Shows, Kids' TV, TV Comedies" 'Sports Movies'
#  'Action & Adventure, Anime Features, Classic Movies'
#  'Cult Movies, Independent Movies, Thrillers'
#  'Children & Family Movies, Comedies, Music & Musicals'
#  'International TV Shows, Stand-Up Comedy & Talk Shows'
#  'Action & Adventure, Comedies, Horror Movies'
#  'Dramas, Faith & Spirituality, Independent Movies'
#  'Documentaries, LGBTQ Movies, Music & Musicals'
#  'British TV Shows, Crime TV Shows, TV Dramas'
#  'International TV Shows, Korean TV Shows, Reality TV'
#  'British TV Shows, International TV Shows, Stand-Up Comedy & Talk Shows'
#  'Anime Features, Children & Family Movies, International Movies'
#  'International Movies, Sports Movies'
#  'Horror Movies, Independent Movies, Sci-Fi & Fantasy'
#  'Crime TV Shows, TV Dramas, TV Horror' 'TV Action & Adventure, TV Dramas'
#  'Comedies, Dramas, Faith & Spirituality' 'Classic & Cult TV, TV Comedies'
#  'Documentaries, Dramas, International Movies'
#  "Classic & Cult TV, Kids' TV, Spanish-Language TV Shows"
#  'Documentaries, International Movies, LGBTQ Movies'
#  'Action & Adventure, Documentaries, Sports Movies'
#  'Action & Adventure, Comedies, Music & Musicals'
#  'Stand-Up Comedy & Talk Shows, TV Mysteries, TV Sci-Fi & Fantasy'
#  'Action & Adventure, Thrillers' 'TV Comedies, Teen TV Shows'
#  'Children & Family Movies, Documentaries, International Movies'
#  'TV Dramas, TV Sci-Fi & Fantasy, TV Thrillers'
#  'Dramas, Faith & Spirituality, Romantic Movies'
#  'Classic & Cult TV, TV Action & Adventure, TV Sci-Fi & Fantasy'
#  'TV Sci-Fi & Fantasy, TV Thrillers'
#  'Cult Movies, Dramas, Independent Movies'
#  'Classic Movies, Comedies, Independent Movies' 'Dramas, LGBTQ Movies'
#  'Action & Adventure, Cult Movies, Dramas'
#  'Comedies, Independent Movies, Music & Musicals'
#  'Classic & Cult TV, TV Sci-Fi & Fantasy'
#  'Classic & Cult TV, Crime TV Shows, TV Dramas'
#  'Action & Adventure, International Movies, Thrillers'
#  'Children & Family Movies, Dramas, Music & Musicals'
#  'TV Dramas, TV Mysteries, TV Thrillers'
#  'Romantic TV Shows, Spanish-Language TV Shows, TV Dramas'
#  'Independent Movies, Romantic Movies' 'Classic Movies, Documentaries'
#  'British TV Shows, Romantic TV Shows, TV Dramas'
#  'Reality TV, Teen TV Shows'
#  'Action & Adventure, Anime Features, Horror Movies'
#  'Comedies, Music & Musicals, Romantic Movies'
#  'Crime TV Shows, Romantic TV Shows, Spanish-Language TV Shows'
#  'Classic Movies, Cult Movies, Documentaries'
#  'Crime TV Shows, TV Comedies' 'TV Action & Adventure, TV Comedies'
#  'British TV Shows, TV Horror, TV Thrillers'
#  'British TV Shows, TV Dramas, TV Sci-Fi & Fantasy'
#  'British TV Shows, Docuseries, Reality TV'
#  'Crime TV Shows, TV Dramas, TV Sci-Fi & Fantasy'
#  'Documentaries, Faith & Spirituality, Music & Musicals'
#  'Children & Family Movies, Comedies, Cult Movies'
#  'Classic & Cult TV, TV Horror, TV Mysteries'
#  'Romantic TV Shows, TV Dramas, TV Sci-Fi & Fantasy'
#  'British TV Shows, International TV Shows, TV Horror'
#  "Classic & Cult TV, Kids' TV, TV Comedies"
#  'Children & Family Movies, Documentaries, Sports Movies'
#  'Docuseries, Stand-Up Comedy & Talk Shows'
#  'Children & Family Movies, Classic Movies, Comedies']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5837 entries, 0 to 5836
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   show_id         5837 non-null   int64
#  1   title           5837 non-null   object
#  2   director        5837 non-null   object
#  3   cast            5837 non-null   object
#  4   country         5837 non-null   object
#  5   date_added      5837 non-null   datetime64[ns]
#  6   release_year    5837 non-null   int64
#  7   rating          5837 non-null   object
#  8   duration        5837 non-null   object
#  9   listed_in       5837 non-null   object
#  10  description     5837 non-null   object
#  11  type            5837 non-null   object
#  12  year_added      5837 non-null   int32
#  13  month_added     5837 non-null   int32
#  14  movie_duration  5837 non-null   float64
#  15  show_duration   5837 non-null   float64
# dtypes: datetime64[ns](1), float64(2), int32(2), int64(2), object(9)
# memory usage: 684.2+ KB
# None

# %%
# Checking Unique Values in cast Column
print(netflix_data['cast'].unique())

# Split the cast Column into list
netflix_data_exploded['cast_split'] = netflix_data_exploded['cast'].str.split(',')

# Removes Spaces
netflix_data_exploded['cast_split'] = netflix_data_exploded['cast_split'].apply(lambda x: [i.strip() for i in x])

# Explode into multiple rows not columns
netflix_data_exploded = netflix_data_exploded.explode('cast_split')
# Out:
# ['Ha Ji-won, Yoon Kye-sang, Jang Seung-jo, Kang Bu-ja, Lee Jae-ryong, Min Jin-woong, Kim Won-hae, Yoo Teo'
#  'Christian Morales'
#  'Sonam Kapoor, Dulquer Salmaan, Sanjay Kapoor, Sikander Kher, Angad Bedi, Koel Purie, Pooja Bhamrah, Manu Rishi Chadha'
#  ...
#  'Corey Feldman, Tony Todd, Tara Leigh, Erin Way, Mark Alan, Stuart Pankin'
#  'Anders W. Berthelsen, Rebecka Hemse, Nikolaj Lie Kaas, Charlotte Fich, Dejan Cukic, Karsten Jansfort, Flemming Enevold, Bent Mejding, Ewa Fröling, Josephine Raahauge, Timm Vladimir, Ditte Hansen'
#  'Barbara King, Shaana Diya, John Krisiukenas, Yoriko Haraguchi, David Crane, Chad Thomas']

# %%
# insights

# Movies vs TV shows Counts
types = netflix_data['type'].value_counts()
print(types)
# Out:
# type
# Movie      3939
# TV Show    1898
# Name: count, dtype: int64

# %%
# Trend Over Years
trend = netflix_data.groupby(['year_added', 'type'])['show_id'].count()
print(trend)
# Out:
# year_added  type
# 1963        TV Show       1
# 1967        TV Show       1
# 1968        TV Show       1
# 1974        TV Show       1
# 1977        TV Show       1
# 1986        TV Show       1
# 1988        TV Show       1
# 1990        TV Show       2
# 1992        TV Show       2
# 1993        TV Show       1
# 1995        TV Show       1
# 1997        TV Show       2
# 1998        TV Show       2
# 1999        TV Show       1
# 2000        TV Show       1
# 2001        TV Show       1
# 2003        TV Show       3
# 2004        TV Show       2
# 2005        TV Show       4
# 2006        TV Show       3
# 2007        TV Show       3
# 2008        Movie         1
#             TV Show       8
# 2009        Movie         2
#             TV Show       3
# 2010        Movie         1
#             TV Show       9
# 2011        Movie        13
#             TV Show       5
# 2012        Movie         4
#             TV Show      18
# 2013        Movie         6
#             TV Show      20
# 2014        Movie        19
#             TV Show      18
# 2015        Movie        58
#             TV Show      55
# 2016        Movie       265
#             TV Show     219
# 2017        Movie       913
#             TV Show     371
# 2018        Movie      1290
#             TV Show     489
# 2019        Movie      1367
#             TV Show     648
# Name: show_id, dtype: int64

# %%
# Content rating Distribution
Content_rating = netflix_data.groupby('rating')['show_id'].count().sort_values(ascending=False)
print(Content_rating)
# Out:
# rating
# TV-MA        1937
# TV-14        1593
# TV-PG         678
# R             439
# PG-13         227
# NR            218
# PG            160
# TV-Y7         156
# TV-G          147
# TV-Y          139
# TV-Y7-FV       92
# G              32
# Not Rated      10
# UR              7
# NC-17           2
# Name: show_id, dtype: int64

# %%
# top 10 Countries 
top_countries = netflix_data.groupby('country')['show_id'].count().sort_values(ascending=False)
print(top_countries.head(10))
# Out:
# country
# United States     1907
# India              697
# Unknown            427
# United Kingdom     336
# Japan              168
# Canada             139
# South Korea        133
# Spain              113
# France              85
# Mexico              80
# Name: show_id, dtype: int64

# %%
# Top 10 Directors 
top_directors = netflix_data.groupby('director')['show_id'].count().sort_values(ascending=False)
print(top_directors.head(10))
# Out:
# director
# Anonymous                 1901
# Raúl Campos, Jan Suter      18
# Marcus Raboy                14
# Jay Karas                   13
# Jay Chapman                 12
# Martin Scorsese              8
# Johnnie To                   8
# Steven Spielberg             8
# Cathy Garcia-Molina          7
# Lance Bangs                  7
# Name: show_id, dtype: int64

# %%
# Top 10 Actors
top_actors = netflix_data_exploded.groupby('cast_split')['show_id'].count().sort_values(ascending=False)
print(top_actors.head(10))
# Out:
# cast_split
# Unknown             997
# Anupam Kher          83
# Shah Rukh Khan       80
# Akshay Kumar         65
# Yuki Kaji            57
# Paresh Rawal         53
# Om Puri              53
# Takahiro Sakurai     53
# Boman Irani          49
# Naseeruddin Shah     48
# Name: show_id, dtype: int64

# %%
# top 10 genres
genres = netflix_data_exploded.groupby('listed_in_split')['show_id'].count().sort_values(ascending=False)
print(genres)
# Out:
# listed_in_split
# International Movies            13081
# Dramas                          12427
# Comedies                         8880
# International TV Shows           7768
# TV Dramas                        5413
# Action & Adventure               4861
# Independent Movies               4297
# TV Comedies                      3218
# Crime TV Shows                   3150
# Children & Family Movies         3039
# Thrillers                        2886
# Romantic Movies                  2746
# Kids' TV                         2360
# Romantic TV Shows                2039
# Horror Movies                    1911
# Sci-Fi & Fantasy                 1544
# Music & Musicals                 1411
# Anime Series                     1364
# TV Action & Adventure            1300
# Spanish-Language TV Shows        1234
# British TV Shows                 1167
# Documentaries                    1090
# Korean TV Shows                   825
# Sports Movies                     789
# TV Mysteries                      723
# TV Sci-Fi & Fantasy               712
# TV Horror                         537
# Classic Movies                    510
# Docuseries                        469
# Teen TV Shows                     450
# TV Thrillers                      447
# Cult Movies                       444
# Anime Features                    415
# LGBTQ Movies                      384
# Stand-Up Comedy                   355
# Reality TV                        342
# Movies                            316
# Faith & Spirituality              311
# Stand-Up Comedy & Talk Shows      220
# Classic & Cult TV                 210
# Science & Nature TV                87
# TV Shows                           43
# Name: show_id, dtype: int64

# %%
# top 10 Actors per genre
actor_genre = netflix_data_exploded.groupby(['listed_in_split', 'cast_split'])['show_id'].count().sort_values(ascending=False).reset_index()
actor_genre_no_unknown = actor_genre[actor_genre['cast_split'] != 'Unknown']
print(actor_genre_no_unknown.head(10))
# Out:
#          listed_in_split      cast_split  show_id
# 9   International Movies     Anupam Kher       26
# 11  International Movies  Shah Rukh Khan       25
# 12                Dramas  Shah Rukh Khan       23
# 13  International Movies    Akshay Kumar       22
# 16  International Movies    Paresh Rawal       18
# 17  International Movies         Om Puri       18
# 18                Dramas     Anupam Kher       18
# 19  International Movies  Kareena Kapoor       17
# 21  International Movies     Boman Irani       15
# 22  International Movies  Gulshan Grover       15

# %%
# Seasonal Trend
seasonal_trend = netflix_data.groupby('month_added')['show_id'].count().sort_values(ascending=False)
print(seasonal_trend.head(5))
# Out:
# month_added
# 1     1031
# 10     580
# 11     544
# 3      504
# 8      454
# Name: show_id, dtype: int64

# %%
valid_movies = netflix_data[netflix_data['movie_duration'] > 0]
longest_movie = valid_movies.loc[valid_movies['movie_duration'].idxmax()]
shortest_movie = valid_movies.loc[valid_movies['movie_duration'].idxmin()]

print("Longest Movie:", longest_movie['title'], f"({longest_movie['movie_duration']} min)")
print("Shortest Movie:", shortest_movie['title'], f"({shortest_movie['movie_duration']} min)")

# Longest & Shortest Show (ignore 0)
valid_shows = netflix_data[netflix_data['show_duration'] > 0]
longest_show = valid_shows.loc[valid_shows['show_duration'].idxmax()]
shortest_show = valid_shows.loc[valid_shows['show_duration'].idxmin()]

print("Longest Show:", longest_show['title'], f"({longest_show['show_duration']} Seasons)")
print("Shortest Show:", shortest_show['title'], f"({shortest_show['show_duration']} Season)")
# Out:
# Longest Movie: Black Mirror: Bandersnatch (312.0 min)
# Shortest Movie: Silent (3.0 min)
# Longest Show: Grey's Anatomy (15.0 Seasons)
# Shortest Show: Chocolate (1.0 Season)

# %%
netflix_data.to_excel("netflix_clean.xlsx", index=False)
